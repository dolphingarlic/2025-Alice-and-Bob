# %%
import dynamiqs as dq
import matplotlib.pyplot as plt
import jax.numpy as jnp

# %%
na = 20  # Hilbert space dimensions


g2 = 1.0  # Two-photon coupling strength
eps_d = -4  # Drive amplitude
eps_z = 1 # z-gate strengh

alpha = jnp.sqrt((-1*eps_d)/g2)
kappa_b = 1  # Decay rate

kappa_2 = 4 * (g2**2) / kappa_b  # Two-photon loss rate

period = jnp.pi/(4*alpha*eps_z)  
T = 10*period # Total simulation time

# %%
a = dq.destroy(na)
dag_a = dq.dag(a)
H_z = eps_z*(dag_a + a)
H = H_z

exp_ops = [dq.dag(a) @ a]

# %%
loss_op = jnp.sqrt(kappa_2) * (a @ a - alpha * alpha * dq.eye(na))

# %%
psi0 = dq.unit(dq.coherent(na, alpha) + dq.coherent(na, -alpha))  # Initial state

# %%
t_save = jnp.linspace(0, T, 1000)
res = dq.mesolve(H, [loss_op], psi0, t_save, exp_ops=exp_ops)
# Out:
# |          |   0.0% ◆ elapsed 1.41ms ◆ remaining 0.00ms

# %%
rho_a = dq.ptrace(res.states, 0)
# Then plot Wigner gif of rho_a
dq.plot.wigner_gif(rho_a)
# Out:
# |▌         |   5.7% ◆ elapsed 42.91ms ◆ remaining 0.00ms
# |██████████| 100.0% ◆ elapsed 407.54ms ◆ remaining 0.00ms
#
#   2%|▏         | 1/50 [00:00<00:38,  1.27it/s]
#   4%|▍         | 2/50 [00:00<00:19,  2.51it/s]
#   6%|▌         | 3/50 [00:01<00:14,  3.31it/s]
#   8%|▊         | 4/50 [00:01<00:10,  4.35it/s]
#  10%|█         | 5/50 [00:01<00:08,  5.22it/s]
#  12%|█▏        | 6/50 [00:01<00:08,  5.45it/s]
#  14%|█▍        | 7/50 [00:01<00:07,  6.02it/s]
#  16%|█▌        | 8/50 [00:01<00:07,  6.00it/s]
#  18%|█▊        | 9/50 [00:01<00:06,  6.53it/s]
#  20%|██        | 10/50 [00:02<00:06,  6.40it/s]
#  22%|██▏       | 11/50 [00:02<00:05,  6.81it/s]
#  24%|██▍       | 12/50 [00:02<00:05,  6.57it/s]
#  26%|██▌       | 13/50 [00:02<00:05,  6.98it/s]
#  28%|██▊       | 14/50 [00:02<00:04,  7.29it/s]
#  30%|███       | 15/50 [00:02<00:05,  6.79it/s]
#  32%|███▏      | 16/50 [00:02<00:04,  7.18it/s]
#  34%|███▍      | 17/50 [00:03<00:04,  6.74it/s]
#  36%|███▌      | 18/50 [00:03<00:04,  7.10it/s]
#  38%|███▊      | 19/50 [00:03<00:04,  7.36it/s]
#  40%|████      | 20/50 [00:03<00:04,  6.92it/s]
#  42%|████▏     | 21/50 [00:03<00:04,  7.17it/s]
#  44%|████▍     | 22/50 [00:03<00:04,  6.77it/s]
#  46%|████▌     | 23/50 [00:03<00:03,  7.10it/s]
#  48%|████▊     | 24/50 [00:04<00:03,  6.71it/s]
#  50%|█████     | 25/50 [00:04<00:03,  7.08it/s]
#  52%|█████▏    | 26/50 [00:04<00:03,  7.39it/s]
#  54%|█████▍    | 27/50 [00:04<00:03,  6.92it/s]
#  56%|█████▌    | 28/50 [00:04<00:04,  4.56it/s]
#  58%|█████▊    | 29/50 [00:05<00:04,  5.23it/s]
#  60%|██████    | 30/50 [00:05<00:03,  5.43it/s]
#  62%|██████▏   | 31/50 [00:05<00:03,  6.04it/s]
#  64%|██████▍   | 32/50 [00:05<00:02,  6.52it/s]
#  66%|██████▌   | 33/50 [00:05<00:02,  6.36it/s]
#  68%|██████▊   | 34/50 [00:05<00:02,  6.77it/s]
#  70%|███████   | 35/50 [00:05<00:02,  6.55it/s]
#  72%|███████▏  | 36/50 [00:06<00:02,  6.98it/s]
#  74%|███████▍  | 37/50 [00:06<00:01,  6.51it/s]
#  76%|███████▌  | 38/50 [00:06<00:01,  6.80it/s]
#  78%|███████▊  | 39/50 [00:06<00:01,  6.57it/s]
#  80%|████████  | 40/50 [00:06<00:01,  7.01it/s]
#  82%|████████▏ | 41/50 [00:06<00:01,  7.24it/s]
#  84%|████████▍ | 42/50 [00:06<00:01,  6.87it/s]
#  86%|████████▌ | 43/50 [00:07<00:00,  7.24it/s]
#  88%|████████▊ | 44/50 [00:07<00:00,  7.49it/s]
#  90%|█████████ | 45/50 [00:07<00:00,  6.98it/s]
#  92%|█████████▏| 46/50 [00:07<00:00,  7.26it/s]
#  94%|█████████▍| 47/50 [00:07<00:00,  6.83it/s]
#  96%|█████████▌| 48/50 [00:07<00:00,  7.15it/s]
#  98%|█████████▊| 49/50 [00:07<00:00,  6.78it/s]
# 100%|██████████| 50/50 [00:08<00:00,  6.24it/s]

# %%
eps_z2 = 2 # z-gate strengh

period2 = jnp.pi/(4*alpha*eps_z2)  
T2 = 10*period # Total simulation time

a = dq.destroy(na)
dag_a = dq.dag(a)
H_z2 = eps_z2*(dag_a + a)
H2 = H_z2

res2 = dq.mesolve(H2, [loss_op], psi0, t_save, exp_ops=exp_ops)

rho_a2 = dq.ptrace(res2.states, 0)
# Then plot Wigner gif of rho_a
dq.plot.wigner_gif(rho_a2)

plt.plot(t_save, dq.expect(dq.parity(na), rho_a).real, label = r'$\epsilon_z = 1$')

plt.plot(t_save, dq.expect(dq.parity(na), rho_a2).real, label = r'$\epsilon_z = 2$')

plt.xlabel(r"Time $t$", fontsize=12)
plt.ylabel(r"Parity", fontsize=12)
plt.ylim(-1, 1.0)
plt.xlim(0,1.5)
plt.legend()

plt.show()
# Out:
# |          |   1.0% ◆ elapsed 5.84ms ◆ remaining 0.00ms
# |██████████| 100.0% ◆ elapsed 311.07ms ◆ remaining 0.00ms
#
#   2%|▏         | 1/50 [00:00<00:35,  1.40it/s]
#   4%|▍         | 2/50 [00:00<00:17,  2.73it/s]
#   6%|▌         | 3/50 [00:01<00:12,  3.63it/s]
#   8%|▊         | 4/50 [00:01<00:10,  4.60it/s]
#  10%|█         | 5/50 [00:01<00:09,  4.93it/s]
#  12%|█▏        | 6/50 [00:01<00:07,  5.65it/s]
#  14%|█▍        | 7/50 [00:01<00:07,  5.68it/s]
#  16%|█▌        | 8/50 [00:01<00:06,  6.28it/s]
#  18%|█▊        | 9/50 [00:01<00:06,  6.15it/s]
#  20%|██        | 10/50 [00:02<00:06,  6.63it/s]
#  22%|██▏       | 11/50 [00:02<00:06,  6.41it/s]
#  24%|██▍       | 12/50 [00:02<00:05,  6.75it/s]
#  26%|██▌       | 13/50 [00:02<00:05,  6.41it/s]
#  28%|██▊       | 14/50 [00:02<00:05,  6.85it/s]
#  30%|███       | 15/50 [00:02<00:05,  6.55it/s]
#  32%|███▏      | 16/50 [00:02<00:04,  6.98it/s]
#  34%|███▍      | 17/50 [00:03<00:04,  7.28it/s]
#  36%|███▌      | 18/50 [00:03<00:04,  6.85it/s]
#  38%|███▊      | 19/50 [00:03<00:04,  7.10it/s]
#  40%|████      | 20/50 [00:03<00:04,  6.74it/s]
#  42%|████▏     | 21/50 [00:03<00:04,  7.11it/s]
#  44%|████▍     | 22/50 [00:03<00:03,  7.38it/s]
#  46%|████▌     | 23/50 [00:03<00:03,  6.97it/s]
#  48%|████▊     | 24/50 [00:04<00:03,  7.24it/s]
#  50%|█████     | 25/50 [00:04<00:03,  6.79it/s]
#  52%|█████▏    | 26/50 [00:04<00:03,  7.14it/s]
#  54%|█████▍    | 27/50 [00:04<00:03,  6.60it/s]
#  56%|█████▌    | 28/50 [00:04<00:03,  6.99it/s]
#  58%|█████▊    | 29/50 [00:04<00:02,  7.29it/s]
#  60%|██████    | 30/50 [00:04<00:02,  6.85it/s]
#  62%|██████▏   | 31/50 [00:05<00:02,  7.20it/s]
#  64%|██████▍   | 32/50 [00:05<00:02,  6.79it/s]
#  66%|██████▌   | 33/50 [00:05<00:04,  3.91it/s]
#  68%|██████▊   | 34/50 [00:05<00:03,  4.62it/s]
#  70%|███████   | 35/50 [00:06<00:03,  4.99it/s]
#  72%|███████▏  | 36/50 [00:06<00:02,  5.62it/s]
#  74%|███████▍  | 37/50 [00:06<00:02,  5.74it/s]
#  76%|███████▌  | 38/50 [00:06<00:01,  6.22it/s]
#  78%|███████▊  | 39/50 [00:06<00:01,  6.71it/s]
#  80%|████████  | 40/50 [00:06<00:01,  6.45it/s]
#  82%|████████▏ | 41/50 [00:06<00:01,  6.90it/s]
#  84%|████████▍ | 42/50 [00:07<00:01,  6.56it/s]
#  86%|████████▌ | 43/50 [00:07<00:01,  6.94it/s]
#  88%|████████▊ | 44/50 [00:07<00:00,  6.63it/s]
#  90%|█████████ | 45/50 [00:07<00:00,  6.94it/s]
#  92%|█████████▏| 46/50 [00:07<00:00,  7.29it/s]
#  94%|█████████▍| 47/50 [00:07<00:00,  6.91it/s]
#  96%|█████████▌| 48/50 [00:07<00:00,  7.20it/s]
#  98%|█████████▊| 49/50 [00:08<00:00,  6.74it/s]
# 100%|██████████| 50/50 [00:08<00:00,  6.15it/s]

# %%
na, nb = 20,5  # Hilbert space dimensions

a, b = dq.destroy(na, nb)
dag_a, dag_b = dq.dag(a), dq.dag(b)
H_2ph = g2 * dag_a @ dag_a @ b + jnp.conj(g2) * a @ a @ dag_b
H_d = jnp.conj(eps_d) * b + eps_d * dag_b
H = H_2ph + H_d


g2 = 1.0  # Two-photon coupling strength
eps_d = -4  # Drive amplitude
eps_z = 1 # z-gate strengh

alpha = jnp.sqrt((-1*eps_d)/g2)
kappa_b = 1  # Decay rate

kappa_2 = 4 * (g2**2) / kappa_b  # Two-photon loss rate

T_z = jnp.pi/(4*alpha*eps_z)  
T = 10*T_z # Total simulation time

# %%
a, b = dq.destroy(na, nb)
dag_a, dag_b = dq.dag(a), dq.dag(b)
H_2ph = g2 * dag_a @ dag_a @ b + jnp.conj(g2) * a @ a @ dag_b
H_d = jnp.conj(eps_d) * b + eps_d * dag_b
H_z = eps_z*(dag_a + a)
H = H_2ph + H_d + H_z

exp_ops = [dq.dag(a) @ a]

# %%
loss_op = jnp.sqrt(kappa_2) * (a @ a - alpha_squared * dq.eye(na,nb))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 loss_op = jnp.sqrt(kappa_2) * (a @ a - alpha_squared * dq.eye(na,nb))
#
# NameError: name 'alpha_squared' is not defined

# %%
psi0 = dq.fock((na,nb), (0,0))  # Initial state

# %%
t_save = jnp.linspace(0, T, 100)
res = dq.mesolve(H, [loss_op], psi0, t_save, exp_ops=exp_ops)

# %%
rho_a = dq.ptrace(res.states, 0)
# Then plot Wigner gif of rho_a
dq.plot.wigner_gif(rho_a)

# %%
plt.plot(t_save, dq.expect(dq.parity(na), rho_a).real)
plt.xlabel(r"Time $t$", fontsize=12)
plt.ylabel(r"Parity", fontsize=12)
plt.ylim(-1, 1.0)
plt.xlim(0,1.5)
